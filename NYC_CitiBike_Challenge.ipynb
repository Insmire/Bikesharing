# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
df = pd.read_csv("Resources/201908-citibike-tripdata.csv/201908-citibike-tripdata.csv")
df.sample(3)
# Out:
#          tripduration                 starttime                  stoptime  \
# 1502536           641  2019-08-20 17:12:34.7790  2019-08-20 17:23:16.0350
# 1818717           822  2019-08-24 22:35:55.2200  2019-08-24 22:49:37.9760
# 26716             630  2019-08-01 11:31:21.9230  2019-08-01 11:41:52.6720
#
#          start station id          start station name  start station latitude  \
# 1502536            3467.0  W Broadway & Spring Street               40.724947
# 1818717            3170.0      W 84 St & Columbus Ave               40.785000
# 26716              3378.0          E 76 St & Park Ave               40.773763
#
#          start station longitude  end station id         end station name  \
# 1502536               -74.001659           382.0  University Pl & E 14 St
# 1818717               -73.972834           495.0         W 47 St & 10 Ave
# 26716                 -73.962221          3459.0          E 53 St & 3 Ave
#
# ...

# %%
# 2. Check the datatypes of your columns. 
df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
df["tripduration"] = pd.to_datetime(df["tripduration"], unit="s")
df.sample(3)
# Out:
#                tripduration                 starttime  \
# 11080   1970-01-01 00:13:06  2019-08-01 08:18:56.5150
# 1485940 1970-01-01 00:09:06  2019-08-20 13:15:41.7190
# 358969  1970-01-01 00:26:50  2019-08-05 16:45:22.7360
#
#                          stoptime  start station id  \
# 11080    2019-08-01 08:32:03.2720             335.0
# 1485940  2019-08-20 13:24:48.6440            3141.0
# 358969   2019-08-05 17:12:13.6710             281.0
#
#                         start station name  start station latitude  \
# 11080             Washington Pl & Broadway               40.729039
# 1485940                    1 Ave & E 68 St               40.765005
# 358969   Grand Army Plaza & Central Park S               40.764397
#
#          start station longitude  end station id       end station name  \
# 11080                 -73.994046           351.0   Front St & Maiden Ln
# 1485940               -73.958185          3362.0  Madison Ave & E 82 St
# ...

# %%
# 4. Check the datatypes of your columns. 
df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
df.to_csv("C:/Users/gilig/Class/Bikesharing/new-201908-citibike-tripdata.csv", index=False)
